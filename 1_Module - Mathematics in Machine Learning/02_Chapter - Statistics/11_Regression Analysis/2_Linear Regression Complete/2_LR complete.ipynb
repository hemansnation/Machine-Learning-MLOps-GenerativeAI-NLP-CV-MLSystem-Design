# %% [markdown]
# # Regression Model
#
# <img src='q.png' />
#
#
# n observation
#
#
# <img src='w.png' />
#
#
# calculate error
#
# <img src='e.png' />

# %% [markdown]
# sum of squared errors (SSE)
#
# <img src='r.png' />
#
# calculate b1 and b0
#
# <img src='t.png' />

# %% [markdown]
# <img src='one.png' />
#
# <img src='two.png' />
#
# <img src='three.png' />

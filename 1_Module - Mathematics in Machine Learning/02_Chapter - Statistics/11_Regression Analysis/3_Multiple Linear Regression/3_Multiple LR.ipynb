# %% [markdown]
# # Multiple Linear Regression
#
# <img src='q.png' />
#
#
# <img src='w.png' />
#
#
#
# <img src='e.png' />

# %%
import numpy as np
import pandas as pd
import statsmodel

# %% [markdown]
# # multicollinearity
#
# <img src='ee.png' />
#
#
# # VIF (Variance Inflation Factor)
#
# <img src='rr.png' />
